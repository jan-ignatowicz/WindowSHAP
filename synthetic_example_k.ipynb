# %% [markdown]
# # Synthetic data

# %%
import timeit
import warnings

import numpy as np
import shap
from sklearn.model_selection import train_test_split
from tensorflow.keras import backend as K

from windowshap import SlidingWindowSHAP, StationaryWindowSHAP, DynamicWindowSHAP

warnings.filterwarnings('ignore')

# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# This function generates a synthetic time series in which each feature sequence is generated using the sin() or cos() function. However, an anomaly interval is inserted at random into one of the feature sequences. If the feature with the anomaly is the first feature, the sample label is 1; otherwise, it is 0.

# %%
def synthetic_data(n_samples=100, n_steps=10, n_features=4, seed=False):

    # Creating input data
    lam = 0.2
    anomaly_lam = 10
    rng = np.random.default_rng(12345)

    eps = rng.normal
    x = np.zeros((n_samples, n_steps, n_features))
    labels = np.zeros(n_samples)
    for i in range(n_samples):
        t0 = rng.integers(1, 5, size=n_features)
        w = rng.integers(1, 5, size=n_features)
        t = np.arange(n_steps)
        for j in range(n_features):
            if j % 2 == 0:
                x[i, :, j] = np.sin((t - t0[j]) / w[j])
            else:
                x[i, :, j] = np.cos((t - t0[j]) / w[j])
            x[i, :, j] = x[i, :, j] + lam * eps(size=n_steps)

        # adding anomaly
        #         anom_dur = np.random.randint(n_steps/10, n_steps/2)
        anom_dur = 20
        anom_start = rng.integers(0, n_steps - anom_dur)
        anom_end = anom_start + anom_dur

        anom_j = rng.integers(0, n_features)
        x[i, anom_start:anom_end, anom_j] += anomaly_lam * eps(size=anom_dur)

        # Creating the label
        labels[i] = 1 if anom_j == 0 else 0
    return x, labels

# %% [markdown]
# Data seperation to test and train

# %%
x, label = synthetic_data(n_samples=10000, n_steps=120, n_features=4)
train_x, test_x, train_y, test_y = train_test_split(x, label, test_size=0.3, random_state=0,
                                                    stratify=label)
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size=0.2, random_state=0,
                                                  stratify=train_y)

# %%
var = 0
phi_index = 0
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_1[phi_index, :, var], var_name='Observed', plot_type='bar')

# %% [markdown]
# # Prediction Model

# %%
from tensorflow.keras.layers import Dense, Dropout, GRU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import regularizers

num_hidden = [70, 20]
num_neurons = 200
es_patience = 20
epochs = 40
num_output = 1
batch_size = 32
drop_rate = 0.3
reg_rate = 0.004

K.clear_session()
model = Sequential()
input_shape = (x.shape[1], x.shape[2])
model.add(GRU(units=num_neurons, activation='relu', input_shape=input_shape,
              recurrent_dropout=0.1, dropout=0.1))
for i in num_hidden:
    model.add(Dropout(drop_rate))
    model.add(Dense(units=i, activation='relu', kernel_regularizer=regularizers.l2(reg_rate)))
model.add(Dense(units=num_output, activation='sigmoid'))

# Creating and compiling model
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=es_patience)

# Class weights
class_weights = {0: len(train_y) / (train_y == 0).sum(),
                 1: len(train_y) / (train_y == 1).sum()}

model.compile(optimizer=SGD(learning_rate=0.01, clipvalue=0.5), loss='binary_crossentropy',
              metrics=['accuracy'])
# model.build(input_shape)
model.summary()
train_history = model.fit(train_x, train_y, batch_size=batch_size,
                          epochs=epochs, verbose=2,
                          validation_data=(val_x, val_y),
                          class_weight=class_weights,
                          callbacks=[es])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 200)               123600
#
#  dropout (Dropout)           (None, 200)               0
#
#  dense (Dense)               (None, 70)                14070
#
#  dropout_1 (Dropout)         (None, 70)                0
#
#  dense_1 (Dense)             (None, 20)                1420
#
#  dense_2 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 139111 (543.40 KB)
# Trainable params: 139111 (543.40 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 175/175 - 23s - loss: 1.9231 - accuracy: 0.3452 - val_loss: 1.2192 - val_accuracy: 0.5236 - 23s/epoch - 129ms/step
# Epoch 2/40
# 175/175 - 22s - loss: 1.9033 - accuracy: 0.5134 - val_loss: 1.2004 - val_accuracy: 0.6207 - 22s/epoch - 126ms/step
# Epoch 3/40
# 175/175 - 22s - loss: 1.8878 - accuracy: 0.5121 - val_loss: 1.1818 - val_accuracy: 0.6979 - 22s/epoch - 126ms/step
# Epoch 4/40
# 175/175 - 22s - loss: 1.8737 - accuracy: 0.5232 - val_loss: 1.1645 - val_accuracy: 0.7314 - 22s/epoch - 126ms/step
# Epoch 5/40
# 175/175 - 22s - loss: 1.8591 - accuracy: 0.5800 - val_loss: 1.1556 - val_accuracy: 0.6507 - 22s/epoch - 126ms/step
# Epoch 6/40
# 175/175 - 22s - loss: 1.8442 - accuracy: 0.5693 - val_loss: 1.1446 - val_accuracy: 0.5957 - 22s/epoch - 126ms/step
# Epoch 7/40
# 175/175 - 22s - loss: 1.8300 - accuracy: 0.5471 - val_loss: 1.1318 - val_accuracy: 0.5821 - 22s/epoch - 126ms/step
# Epoch 8/40
# 175/175 - 22s - loss: 1.8170 - accuracy: 0.5055 - val_loss: 1.1148 - val_accuracy: 0.6471 - 22s/epoch - 126ms/step
# Epoch 9/40
# 175/175 - 22s - loss: 1.8012 - accuracy: 0.5564 - val_loss: 1.1061 - val_accuracy: 0.5693 - 22s/epoch - 125ms/step
# Epoch 10/40
# 175/175 - 22s - loss: 1.7883 - accuracy: 0.5250 - val_loss: 1.0849 - val_accuracy: 0.6793 - 22s/epoch - 127ms/step
# Epoch 11/40
# 175/175 - 22s - loss: 1.7712 - accuracy: 0.5846 - val_loss: 1.0745 - val_accuracy: 0.6529 - 22s/epoch - 126ms/step
# Epoch 12/40
# 175/175 - 22s - loss: 1.7539 - accuracy: 0.5852 - val_loss: 1.0580 - val_accuracy: 0.6729 - 22s/epoch - 126ms/step
# Epoch 13/40
# 175/175 - 22s - loss: 1.6773 - accuracy: 0.6391 - val_loss: 0.8725 - val_accuracy: 0.9286 - 22s/epoch - 126ms/step
# Epoch 14/40
# 175/175 - 22s - loss: 0.8223 - accuracy: 0.9789 - val_loss: 0.5175 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 15/40
# 175/175 - 22s - loss: 0.5061 - accuracy: 0.9986 - val_loss: 0.4139 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 16/40
# 175/175 - 22s - loss: 0.4160 - accuracy: 0.9996 - val_loss: 0.3751 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 17/40
# 175/175 - 22s - loss: 0.3848 - accuracy: 0.9993 - val_loss: 0.3577 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 18/40
# 175/175 - 22s - loss: 0.3581 - accuracy: 0.9998 - val_loss: 0.3429 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 19/40
# 175/175 - 22s - loss: 0.3463 - accuracy: 0.9996 - val_loss: 0.3317 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 20/40
# 175/175 - 22s - loss: 0.3311 - accuracy: 1.0000 - val_loss: 0.3212 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 21/40
# 175/175 - 22s - loss: 0.3197 - accuracy: 1.0000 - val_loss: 0.3117 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 22/40
# 175/175 - 22s - loss: 0.3102 - accuracy: 1.0000 - val_loss: 0.3028 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 23/40
# 175/175 - 22s - loss: 0.3018 - accuracy: 0.9998 - val_loss: 0.2942 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 24/40
# 175/175 - 22s - loss: 0.2950 - accuracy: 0.9998 - val_loss: 0.2866 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 25/40
# 175/175 - 22s - loss: 0.2847 - accuracy: 1.0000 - val_loss: 0.2785 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 26/40
# 175/175 - 22s - loss: 0.2766 - accuracy: 1.0000 - val_loss: 0.2708 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 27/40
# 175/175 - 22s - loss: 0.2686 - accuracy: 1.0000 - val_loss: 0.2633 - val_accuracy: 1.0000 - 22s/epoch - 128ms/step
# Epoch 28/40
# 175/175 - 157s - loss: 0.2612 - accuracy: 1.0000 - val_loss: 0.2561 - val_accuracy: 1.0000 - 157s/epoch - 896ms/step
# Epoch 29/40
# 175/175 - 22s - loss: 0.2540 - accuracy: 1.0000 - val_loss: 0.2491 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 30/40
# 175/175 - 22s - loss: 0.2504 - accuracy: 0.9998 - val_loss: 0.2428 - val_accuracy: 1.0000 - 22s/epoch - 128ms/step
# Epoch 31/40
# 175/175 - 23s - loss: 0.2413 - accuracy: 1.0000 - val_loss: 0.2362 - val_accuracy: 1.0000 - 23s/epoch - 129ms/step
# Epoch 32/40
# 175/175 - 23s - loss: 0.2343 - accuracy: 1.0000 - val_loss: 0.2297 - val_accuracy: 1.0000 - 23s/epoch - 131ms/step
# Epoch 33/40
# 175/175 - 22s - loss: 0.2278 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 1.0000 - 22s/epoch - 128ms/step
# Epoch 34/40
# 175/175 - 23s - loss: 0.2216 - accuracy: 1.0000 - val_loss: 0.2174 - val_accuracy: 1.0000 - 23s/epoch - 134ms/step
# Epoch 35/40
# 175/175 - 23s - loss: 0.2154 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 1.0000 - 23s/epoch - 129ms/step
# Epoch 36/40
# 175/175 - 24s - loss: 0.2098 - accuracy: 1.0000 - val_loss: 0.2057 - val_accuracy: 1.0000 - 24s/epoch - 134ms/step
# Epoch 37/40
# 175/175 - 23s - loss: 0.2039 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 1.0000 - 23s/epoch - 131ms/step
# Epoch 38/40
# 175/175 - 23s - loss: 0.1984 - accuracy: 1.0000 - val_loss: 0.1947 - val_accuracy: 1.0000 - 23s/epoch - 130ms/step
# Epoch 39/40
# 175/175 - 23s - loss: 0.1930 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 1.0000 - 23s/epoch - 130ms/step
# Epoch 40/40
# 175/175 - 23s - loss: 0.1877 - accuracy: 1.0000 - val_loss: 0.1843 - val_accuracy: 1.0000 - 23s/epoch - 130ms/step

# %%
from sklearn.metrics import roc_auc_score, accuracy_score

print(roc_auc_score(test_y, model.predict(test_x)))
print(accuracy_score(test_y, np.round(model.predict(test_x))))
# Out:
# 94/94 [==============================] - 2s 21ms/step
# 1.0
# 94/94 [==============================] - 2s 21ms/step
# 1.0

# %% [markdown]
# ## SHAP interpretation

# %%
num_background = 50
num_test = 28
background_data, test_data = train_x[:num_background], test_x[num_test:num_test + 2]

# %% [markdown]
# ## 1- Stationary WindowSHAP

# %%
tic = timeit.default_timer()
ts_phi_1 = np.zeros((len(test_data),test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    window_len = 20
    gtw = StationaryWindowSHAP(model, window_len, B_ts=background_data, test_ts=test_data[i:i+1], model_type='lstm')
    ts_phi_1[i,:,:] = gtw.shap_values()
print('Total time: ' + str(timeit.default_timer()-tic))
# Out:
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 3275/3275 [==============================] - 68s 21ms/step
# 100%|██████████| 1/1 [02:03<00:00, 123.04s/it]
# 2/2 [==============================] - 0s 42ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 22ms/step
# 3275/3275 [==============================] - 70s 21ms/step
# 100%|██████████| 1/1 [02:04<00:00, 124.03s/it]
# Total time: 247.4490129170008

# %% [markdown]
# ## 2- Sliding WindowSHAP

# %%
tic = timeit.default_timer()
ts_phi_2 = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    window_len = 20
    stride = 10
    gtw = SlidingWindowSHAP(model, stride, window_len, background_data, test_data[i:i + 1],
                            model_type='lstm')
    ts_phi_2[i, :, :] = gtw.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 15ms/step
# 63/63 [==============================] - 1s 22ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.82s/it]
# 2/2 [==============================] - 0s 24ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 22ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.89s/it]
# 2/2 [==============================] - 0s 19ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 21ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.82s/it]
# 2/2 [==============================] - 0s 19ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 15ms/step
# 63/63 [==============================] - 1s 21ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.81s/it]
# 2/2 [==============================] - 0s 24ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 15ms/step
# 63/63 [==============================] - 1s 22ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.82s/it]
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 15ms/step
# 63/63 [==============================] - 1s 21ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.82s/it]
# 2/2 [==============================] - 0s 19ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 22ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.83s/it]
# 2/2 [==============================] - 0s 19ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 21ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.77s/it]
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 21ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.80s/it]
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 21ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.80s/it]
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 19ms/step
# 63/63 [==============================] - 1s 22ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.88s/it]
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 20ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.75s/it]
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 15ms/step
# 63/63 [==============================] - 1s 21ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.77s/it]
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 17ms/step
# 63/63 [==============================] - 1s 21ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.80s/it]
# 2/2 [==============================] - 0s 19ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 21ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.81s/it]
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 22ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.82s/it]
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 21ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.77s/it]
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 20ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.76s/it]
# 2/2 [==============================] - 0s 19ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 21ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.79s/it]
# 2/2 [==============================] - 0s 23ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 23ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.91s/it]
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 19ms/step
# 63/63 [==============================] - 1s 22ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 63/63 [==============================] - 1s 21ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.78s/it]
# Total time: 41.686919749947265

# %% [markdown]
# ## 3- Dynamic WindowSHAP

# %%
print(len(test_data))
tic = timeit.default_timer()
ts_phi_3 = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    delta = 0.3
    n_w = 8
    btw = DynamicWindowSHAP(model, delta, n_w, background_data, test_data[i:i + 1],
                            model_type='lstm')
    ts_phi_3[i, :, :] = btw.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# 2
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 18ms/step
# 13/13 [==============================] - 0s 25ms/step
# 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# 2/2 [==============================] - 0s 19ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 16/16 [==============================] - 0s 22ms/step
# 100%|██████████| 1/1 [00:00<00:00,  1.97it/s]
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 20ms/step
# 19/19 [==============================] - 0s 23ms/step
# 100%|██████████| 1/1 [00:00<00:00,  1.60it/s]
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 17ms/step
# 22/22 [==============================] - 1s 26ms/step
# 100%|██████████| 1/1 [00:00<00:00,  1.29it/s]
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 17ms/step
# 29/29 [==============================] - 1s 23ms/step
# 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 17ms/step
# 41/41 [==============================] - 1s 25ms/step
# 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# 2/2 [==============================] - 0s 24ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 18ms/step
# 3241/3241 [==============================] - 70s 22ms/step
# 100%|██████████| 1/1 [01:29<00:00, 89.31s/it]
# 1/2 [==============>...............] - ETA: 0s
# 2/2 [==============================] - 0s 35ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 25ms/step
# 13/13 [==============================] - 0s 21ms/step
# 100%|██████████| 1/1 [00:00<00:00,  2.34it/s]
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# 22/22 [==============================] - 0s 22ms/step
# 100%|██████████| 1/1 [00:00<00:00,  1.47it/s]
# Total time: 95.95711083407514

# %%
from utils import heat_map

var = 0
phi_index = 0

heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_1[phi_index, :, var], var_name='Observed', plot_type='bar')


heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_2[phi_index, :, var], var_name='Observed', plot_type='bar')

heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_3[phi_index, :, var], 
         var_name='Variable', plot_type='bar')
